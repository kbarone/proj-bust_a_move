# %%
import json
from urllib.request import urlopen
import pandas as pd
import plotly.express as px

# %%
with urlopen('https://raw.githubusercontent.com/plotly/datasets/master/geojson-counties-fips.json') as response:
    counties = json.load(response)

counties["features"][0]

df = pd.read_csv("google_mobility_county.csv")

recent_data = df[(df["year"] == 2022) & (df["month"] == 2) & (df["day"]== 12)]
recent_data = recent_data.rename(columns={"countyfips": "fips"})
recent_data_gps = recent_data[recent_data["gps_parks"] != "."]
recent_data_gps
# Out:
#          year  month  day   fips gps_retail_and_recreation  \
# 1812936  2022      2   12   1003                     .0129
# 1812965  2022      2   12   1073                     -.127
# 1812969  2022      2   12   1083                    -.0357
# 1812972  2022      2   12   1089                     -.121
# 1812976  2022      2   12   1097                     -.104
# ...       ...    ...  ...    ...                       ...
# 1815096  2022      2   12  55133                     -.136
# 1815099  2022      2   12  55139                    -.0971
# 1815106  2022      2   12  56021                     -.119
# 1815108  2022      2   12  56025                     -.121
# 1815112  2022      2   12  56039                     -.103
#
#         gps_grocery_and_pharmacy gps_parks gps_transit_stations  \
# 1812936                     .189      .214               -.0229
# 1812965                      .01     .0764                -.284
# 1812969                     .103     .0414                    .
# 1812972                    .0371      .136                -.296
# 1812976                    .0257    -.0786                -.164
# ...                          ...       ...                  ...
# 1815096                      .03     .0829                    .
# 1815099                    .0229      .253                    .
# 1815106                    -.106    -.0129                -.179
# 1815108                     -.07       .03               -.0486
# 1815112                        .      .179               -.0471
#
#         gps_workplaces gps_residential gps_away_from_home
# 1812936         -.0343           .0271             -.0326
# 1812965          -.149           .0471             -.0572
# 1812969         -.0814           .0443             -.0532
# 1812972          -.171           .0586             -.0695
# 1812976          -.111           .0343             -.0425
# ...                ...             ...                ...
# 1815096           -.17           .0643             -.0723
# 1815099          -.166             .04             -.0458
# 1815106         -.0986           .0357             -.0437
# 1815108          -.177           .0329             -.0404
# 1815112          -.139               .                  .
#
# [632 rows x 11 columns]

# %%
fig = px.choropleth(recent_data, geojson=counties, locations='fips', color='gps_parks',
                           color_continuous_scale="Viridis",
                           range_color=(0, 12),
                           scope="usa",
                           labels={'gps_parks':'change in mobility near parks'}
                          )
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()
